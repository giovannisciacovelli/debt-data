# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
import wbgapi as wb

# %%
# wb.data.DataFrame(['SP.POP.TOTL', 'EN.ATM.CO2E.KT'], time=range(2000, 2020), skipBlanks=True, columns='series')
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2021-12-16
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
indicators = requests.get("http://api.worldbank.org/v2/indicator?format=json&source=22&per_page=1800")
indicatorsJSON = indicators.json()
print("There are " + str(indicatorsJSON[0]["total"]) + " ExtDebt indicators")
# Out:
# There are 1800 ExtDebt indicators

# %%
ids={'Ext. Assets in Debt Instruments, General Government, All maturities, All instruments, USD': 'DT.DOD.DECT.CD.GG.AR.EA.US'}

# %%
# indicatorsJSON[1]

# %%
# Use the indicator code to define the "indicator" variable
indicator = "DT.DOD.DECT.CD.GG.AR.EA.US"

# Parse through the response to get the "sourceNote" or definition for the desired indicator
for dict_entity in indicatorsJSON[1]:
    if dict_entity["id"] == indicator:
        print(dict_entity["sourceNote"])

# %%
7070.7*1000/(6954665+968409)
# Out:
# 0.8924187758438202

# %%
wb.series.info(q='DT.DOD.DECT.CD.GG.AR.EA.US')

# %%
df = wb.data.DataFrame('DT.DOD.DECT.CD.GG.AR.EA.US', 'AUT', index='time')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/wbgapi/__init__.py in _queryAPI(url)
#     527     try:
# --> 528         result = response.json()
#     529     except:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     336         """
# ...

# %%
wb.data.DataFrame('NY.GDP.PCAP.CD', ['BRA', 'ARG', 'COL'],
                  range(2000, 2020), index='time')
# Out:
#                  ARG           BRA          COL
# time
# YR2000   7708.099115   3749.910848  2520.481089
# YR2001   7208.373114   3160.249345  2439.682456
# YR2002   2593.404563   2839.491501  2396.627127
# YR2003   3349.806300   3070.436419  2281.401762
# YR2004   4277.721573   3637.313890  2782.623185
# YR2005   5109.852245   4790.456566  3414.465158
# YR2006   5919.012338   5886.391522  3741.092837
# YR2007   7245.446857   7348.187963  4714.073055
# YR2008   9020.873323   8831.183643  5472.536530
# YR2009   8225.137583   8597.794335  5193.241458
# YR2010  10385.964432  11286.071540  6336.709474
# YR2011  12848.864197  13245.387370  7335.166934
# YR2012  13082.664326  12370.223255  8050.255372
# YR2013  13080.254732  12300.386712  8218.347844
# YR2014  12334.798245  12112.834955  8114.343921
# YR2015  13789.060425   8813.989806  6175.876030
# YR2016  12790.242473   8710.063290  5870.777957
# YR2017  14613.041825   9928.675897  6376.706716
# ...

# %%
# indicators.json()

# %%
# for i in indicatorsJSON[1]:
#     IDSindicators = (i["id"],i["name"])
#     print(IDSindicators) # to view the indicator ids and names, remove the "#" at the beginning of the print command

# %%
wb.source.concepts(db=22)
# Out:
# {'economy': {'key': 'country', 'value': 'Country'},
#  'series': {'key': 'series', 'value': 'Series'},
#  'time': {'key': 'time', 'value': 'Time'}}

# %%
wb.data.DataFrame('SP.POP.TOTL', time=range(2010, 2020, 2), labels=True)
# Out:
#                                 Country       YR2010       YR2012  \
# economy
# ZWE                            Zimbabwe   12697728.0   13115149.0
# ZMB                              Zambia   13605986.0   14465148.0
# YEM                         Yemen, Rep.   23154854.0   24473176.0
# PSE                  West Bank and Gaza    3786161.0    3979998.0
# VIR               Virgin Islands (U.S.)     108357.0     108188.0
# ...                                 ...          ...          ...
# CEB      Central Europe and the Baltics  104421447.0  103935318.0
# CSS              Caribbean small states    6973193.0    7072640.0
# ARB                          Arab World  354890097.0  371437642.0
# AFW          Africa Western and Central  350556886.0  370243017.0
# AFE         Africa Eastern and Southern  518468229.0  547482863.0
#
#               YR2014       YR2016       YR2018
# economy
# ZWE       13586710.0   14030338.0   14438812.0
# ZMB       15399793.0   16363449.0   17351714.0
# ...
